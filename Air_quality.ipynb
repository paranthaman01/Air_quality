# %% [markdown]
# ## 7. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("C:\\Users\\paran\OneDrive\Desktop\Book1.csv")

# %%
df.isnull().sum()
# Out:
# SNO             0
# Temp            0
# Hum             0
# LPG             0
# CH3             0
# S               0
# CO              0
# AQI category    0
# dtype: int64

# %%
df.dropna()
# Out:
#     SNO  Temp  Hum  LPG  CH3   S  CO AQI category
# 0     1    38   90   50  150  25  40         high
# 1     2    30   50   10   50  10  22         good
# 2     3    36   60   15   98  15  32     moderate
# 3     4    35   70   14   96  16  34     moderate
# 4     5    28   67   10   45  10  20         good
# 5     6    34   65   16   99  15  33     moderate
# 6     7    39   85   46  136  26  38         high
# 7     8    38   88   45  124  30  39         high
# 8     9    27   58   10   81  12  23         good
# 9    10    27   52   12   80  14  20         good
# 10   11    29   49   11   75  10  22         good
# 11   12    38   80   38  142  22  45         high
# 12   13    26   62   12   70  11  22         good
# 13   14    37   70   15   92  18  32     moderate
# 14   15    36   69   16   95  19  30     moderate
# 15   16    36   70   18   98  16  34     moderate
# 16   17    35   65   16   90  15  32     moderate
# 17   18    28   69   11   56  13  20     moderate
# 18   19    39   48   42  120  25  39         high
# 19   20    38   86   46  125  30  40     moderate

# %%
# view dimensions of dataset

df.shape
# Out:
# (20, 8)

# %%
df.tail()
# Out:
#     SNO  Temp  Hum  LPG  CH3   S  CO AQI category
# 15   16    36   70   18   98  16  34     moderate
# 16   17    35   65   16   90  15  32     moderate
# 17   18    28   69   11   56  13  20     moderate
# 18   19    39   48   42  120  25  39         high
# 19   20    38   86   46  125  30  40     moderate

# %% [markdown]
# ### View top 5 rows of dataset

# %%
# preview the dataset

df.head()
# Out:
#    SNO  Temp  Hum  LPG  CH3   S  CO AQI category
# 0    1    38   90   50  150  25  40         high
# 1    2    30   50   10   50  10  22         good
# 2    3    36   60   15   98  15  32     moderate
# 3    4    35   70   14   96  16  34     moderate
# 4    5    28   67   10   45  10  20         good

# %%
df.plot()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(df)

# %%
sns.set_style('whitegrid')
sns.countplot(x='CH3',data=df,palette='RdBu_r')
# Out:
# <AxesSubplot:xlabel='CH3', ylabel='count'>

# %%
correlation=df.corr()
correlation
# Out:
#            SNO      Temp       Hum       LPG       CH3         S        CO
# SNO   1.000000  0.095733 -0.048918  0.066149  0.023025  0.192672  0.083462
# Temp  0.095733  1.000000  0.577464  0.750760  0.836312  0.821649  0.936137
# Hum  -0.048918  0.577464  1.000000  0.681961  0.654484  0.710670  0.646267
# LPG   0.066149  0.750760  0.681961  1.000000  0.883796  0.938491  0.828608
# CH3   0.023025  0.836312  0.654484  0.883796  1.000000  0.866845  0.929022
# S     0.192672  0.821649  0.710670  0.938491  0.866845  1.000000  0.848633
# CO    0.083462  0.936137  0.646267  0.828608  0.929022  0.848633  1.000000

# %%
sns.heatmap(correlation,cmap="RdYlGn",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### View summary of dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   SNO           20 non-null     int64
#  1   Temp          20 non-null     int64
#  2   Hum           20 non-null     int64
#  3   LPG           20 non-null     int64
#  4   CH3           20 non-null     int64
#  5   S             20 non-null     int64
#  6   CO            20 non-null     int64
#  7   AQI category  20 non-null     object
# dtypes: int64(7), object(1)
# memory usage: 1.4+ KB

# %%
plt.scatter(df['Temp'], df['CH3'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Temp')
plt.ylabel('CH3')
 
plt.show()

# %%
plt.scatter(df['Temp'], df['Hum'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Temp')
plt.ylabel('Hum')
 
plt.show()

# %%
plt.scatter(df['Temp'], df['S'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Temp')
plt.ylabel('S')
 
plt.show()

# %%
plt.scatter(df['Temp'], df['CO'])
 
# Adding Title to the Plot
plt.title("Scatter Plot")
 
# Setting the X and Y labels
plt.xlabel('Temp')
plt.ylabel('CO')
 
plt.show()

# %% [markdown]
# ### Frequency distribution of values in variables
#
# Now, I will check the frequency counts of categorical variables.

# %%
col_names = ['Temp','Hum','CH3','S','CO']


for col in col_names:
    
    print(df[col].value_counts())
# Out:
# 38    4
# 36    3
# 35    2
# 28    2
# 39    2
# 27    2
# 30    1
# 34    1
# 29    1
# 26    1
# 37    1
# Name: Temp, dtype: int64
# 70    3
# 65    2
# 69    2
# 90    1
# 50    1
# 60    1
# 67    1
# 85    1
# 88    1
# 58    1
# 52    1
# 49    1
# 80    1
# 62    1
# 48    1
# 86    1
# Name: Hum, dtype: int64
# 98     2
# 150    1
# 75     1
# 120    1
# 56     1
# 90     1
# 95     1
# 92     1
# 70     1
# 142    1
# 80     1
# 50     1
# 81     1
# 124    1
# 136    1
# 99     1
# 45     1
# 96     1
# 125    1
# Name: CH3, dtype: int64
# 10    3
# 15    3
# 25    2
# 16    2
# 30    2
# 26    1
# 12    1
# 14    1
# 22    1
# 11    1
# 18    1
# 19    1
# 13    1
# Name: S, dtype: int64
# 22    3
# 32    3
# 20    3
# 40    2
# 34    2
# 39    2
# 33    1
# 38    1
# 23    1
# 45    1
# 30    1
# Name: CO, dtype: int64

# %% [markdown]
# We can see that the `doors` and `persons` are categorical in nature. So, I will treat them as categorical variables.

# %%
df['AQI category'].value_counts()
# Out:
# moderate    9
# good        6
# high        5
# Name: AQI category, dtype: int64

# %% [markdown]
# ### Missing values in variables

# %%
# check missing values in variables

df.isnull().sum()
# Out:
# SNO             0
# Temp            0
# Hum             0
# LPG             0
# CH3             0
# S               0
# CO              0
# AQI category    0
# dtype: int64

# %% [markdown]
# ## 10. Declare feature vector and target variable

# %%
X = df.drop(['AQI category'], axis=1)

y = df['AQI category']

# %% [markdown]
# ## 11. Split data into separate training and test set

# %%
# split X and y into training and testing sets

from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 3, random_state =0)

# %%
# check the shape of X_train and X_test

X_train.shape, X_test.shape
# Out:
# ((17, 7), (3, 7))

# %% [markdown]
# ## 12. Feature Engineering
#
#
# **Feature Engineering** is the process of transforming raw data into useful features that help us to understand our model better and increase its predictive power. I will carry out feature engineering on different types of variables.
#
#
# First, I will check the data types of variables again.

# %%
# check data types in X_train

X_train.dtypes
# Out:
# SNO     int64
# Temp    int64
# Hum     int64
# LPG     int64
# CH3     int64
# S       int64
# CO      int64
# dtype: object

# %% [markdown]
# ### Encode categorical variables
#
#
# Now, I will encode the categorical variables.

# %%
X_train.head()
# Out:
#     SNO  Temp  Hum  LPG  CH3   S  CO
# 8     9    27   58   10   81  12  23
# 10   11    29   49   11   75  10  22
# 17   18    28   69   11   56  13  20
# 6     7    39   85   46  136  26  38
# 13   14    37   70   15   92  18  32

# %% [markdown]
# We can see that all  the variables are ordinal categorical data type.

# %%
# import category encoders
import category_encoders as ce
from category_encoders import OrdinalEncoder

# %%
# encode variables with ordinal encoding

encoder = ce.OrdinalEncoder(cols=(['SNO','Temp','Hum','CH3','S','CO']))


X_train = encoder.fit_transform(X_train)

X_test = encoder.transform(X_test)

# %%
X_train.head()
# Out:
#     SNO  Temp  Hum  LPG  CH3  S  CO
# 8     1     1    1   10    1  1   1
# 10    2     2    2   11    2  2   2
# 17    3     3    3   11    3  3   3
# 6     4     4    4   46    4  4   4
# 13    5     5    5   15    5  5   5

# %%
X_test.head()
# Out:
#     SNO  Temp  Hum  LPG  CH3   S  CO
# 18 -1.0   4.0 -1.0   42 -1.0  12   8
# 1  -1.0  -1.0 -1.0   10 -1.0   2   2
# 19 -1.0   8.0 -1.0   46 -1.0   9  11

# %% [markdown]
# We now have training and test set ready for model building.

# %% [markdown]
# ## 13. Decision Tree Classifier with criterion gini index

# %%
# import DecisionTreeClassifier

from sklearn.tree import DecisionTreeClassifier

# %%
# instantiate the DecisionTreeClassifier model with criterion gini index

clf_gini = DecisionTreeClassifier(criterion='gini', max_depth=3, random_state=0)


# fit the model
clf_gini.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=0)

# %% [markdown]
# ### Predict the Test set results with criterion gini index

# %%
y_pred_gini = clf_gini.predict(X_test)

# %% [markdown]
# ### Check accuracy score with criterion gini index

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion gini index: {0:0.4f}'. format(accuracy_score(y_test, y_pred_gini)))
# Out:
# Model accuracy score with criterion gini index: 0.6667

# %% [markdown]
# Here, **y_test** are the true class labels and **y_pred_gini** are the predicted class labels in the test-set.

# %% [markdown]
# ### Compare the train-set and test-set accuracy
#
#
# Now, I will compare the train-set and test-set accuracy to check for overfitting.

# %%
y_pred_train_gini = clf_gini.predict(X_train)

y_pred_train_gini
# Out:
# array(['good', 'good', 'good', 'high', 'moderate', 'good', 'moderate',
#        'moderate', 'moderate', 'good', 'high', 'moderate', 'high',
#        'moderate', 'high', 'moderate', 'good'], dtype=object)

# %%
print('Training-set accuracy score: {0:.4f}'. format(accuracy_score(y_train, y_pred_train_gini)))
# Out:
# Training-set accuracy score: 0.9412

# %% [markdown]
# ### Check for overfitting and underfitting

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf_gini.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_gini.score(X_test, y_test)))
# Out:
# Training set score: 0.9412
# Test set score: 0.6667

# %% [markdown]
# ## 14. Decision Tree Classifier with criterion entropy

# %%
# instantiate the DecisionTreeClassifier model with criterion entropy

clf_en = DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)


# fit the model
clf_en.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3, random_state=0)

# %% [markdown]
# ### Predict the Test set results with criterion entropy

# %%
y_pred_en = clf_en.predict(X_test)

# %% [markdown]
# ### Check accuracy score with criterion entropy

# %%
from sklearn.metrics import accuracy_score

print('Model accuracy score with criterion entropy: {0:0.4f}'. format(accuracy_score(y_test, y_pred_en)))
# Out:
# Model accuracy score with criterion entropy: 0.6667

# %% [markdown]
# ### Compare the train-set and test-set accuracy
#
#
# Now, I will compare the train-set and test-set accuracy to check for overfitting.

# %%
y_pred_train_en = clf_en.predict(X_train)

y_pred_train_en
# Out:
# array(['good', 'good', 'good', 'high', 'moderate', 'good', 'moderate',
#        'moderate', 'moderate', 'good', 'high', 'moderate', 'high',
#        'moderate', 'high', 'moderate', 'good'], dtype=object)

# %%
sns.displot(y_pred_train_en)

# %%
print('Training-set accuracy score: {0:0.4f}'. format(accuracy_score(y_train, y_pred_train_en)))
# Out:
# Training-set accuracy score: 0.9412

# %% [markdown]
# ### Check for overfitting and underfitting

# %%
# print the scores on training and test set

print('Training set score: {:.4f}'.format(clf_en.score(X_train, y_train)))

print('Test set score: {:.4f}'.format(clf_en.score(X_test, y_test)))
# Out:
# Training set score: 0.9412
# Test set score: 0.6667

# %%
# Print the Confusion Matrix and slice it into four pieces

from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_en)

print('Confusion matrix\n\n', cm)
# Out:
# Confusion matrix
#
#  [[1 0 0]
#  [0 1 0]
#  [0 1 0]]

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred_en))
# Out:
#               precision    recall  f1-score   support
#
#         good       1.00      1.00      1.00         1
#         high       0.50      1.00      0.67         1
#     moderate       0.00      0.00      0.00         1
#
#     accuracy                           0.67         3
#    macro avg       0.50      0.67      0.56         3
# weighted avg       0.50      0.67      0.56         3
